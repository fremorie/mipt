# %%
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# Функция для вычисления гауссовского ядра:

# %%
def gauss_kernel(ps, xs, h = None):
    if h is None:
        h = 1.0 / np.sqrt(ps.shape[0])

    Ps, Xs = np.meshgrid(ps, xs)
    
    D = np.exp(-(Ps - Xs) ** 2 / h) / np.sqrt(h * np.pi) / ps.shape[0]
    return np.sum(D, axis = 1)

# %%
import scipy.stats as stats

# %% [markdown]
# Генерируем нормальное стандартное распределение:

# %%
distribution = stats.norm(loc = 0.0, scale = 1.0)

# %% [markdown]
# xs - точки, в которых оцениваем плотность;
# ps - наблюдаемые точки.

# %%
xs = np.linspace(-5, 5, num=1000)
ps = distribution.rvs(size = 100)

# %% [markdown]
# Строим на графике настоящую плотность и оцененную:

# %%
plt.plot(xs, gauss_kernel(ps, xs), label = 'Estimated')
plt.plot(xs, distribution.pdf(xs), '--', label = 'True')
plt.scatter(ps, np.zeros_like(ps), alpha = 0.1)
plt.legend()

# %% [markdown]
# Варьируем ширину окна:

# %%
plt.plot(xs, gauss_kernel(ps, xs, 0.01), label = 'Estimated')
plt.plot(xs, distribution.pdf(xs), '--', label = 'True')
plt.scatter(ps, np.zeros_like(ps), alpha = 0.1)
plt.legend()

# %%
plt.plot(xs, gauss_kernel(ps, xs, 1.0), label = 'Estimated')
plt.plot(xs, distribution.pdf(xs), '--', label = 'True')
plt.scatter(ps, np.zeros_like(ps), alpha = 0.1)
plt.legend()
